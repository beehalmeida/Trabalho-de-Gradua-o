# %%
import pandas as pd

# %%
# Loop para ler cada arquivo e converter em dataframe
from google.colab import drive
drive.mount ('/content/drive')

path_in = '/content/drive/My Drive/PYTHON/Dados Atracacao'
# Out:
# Mounted at /content/drive

# %%
# Nome do arquivo local para salvar o CSV
df = pd.read_csv(path_in + "/dataframe_final.csv", encoding="UTF-8")

# %%
# Verificando as primeiras linhas do dataframe final
df.head(5)
# Out:
#    IDAtracacao    CDTUP      IDBerco                Berço  \
# 0       691715  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 1       691712  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 2       691731  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 3       697535  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 4       702879  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
#
#                Porto Atracação Apelido Instalação Portuária  \
# 0  Terminal Graneleiro Hermasa                          NaN
# 1  Terminal Graneleiro Hermasa                          NaN
# 2  Terminal Graneleiro Hermasa                          NaN
# 3  Terminal Graneleiro Hermasa                          NaN
# 4  Terminal Graneleiro Hermasa                          NaN
#
#   Complexo Portuário Tipo da Autoridade Portuária       Data Atracação  \
# 0             Manaus                Porto Privado  28/05/2015 19:23:00
# 1             Manaus                Porto Privado  28/05/2015 10:11:00
# ...

# %%
# checando a estrutura
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701048 entries, 0 to 701047
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     701048 non-null  int64
#  1   CDTUP                           701048 non-null  object
#  2   IDBerco                         698635 non-null  object
#  3   Berço                           698541 non-null  object
#  4   Porto Atracação                 698635 non-null  object
#  5   Apelido Instalação Portuária    252147 non-null  object
#  6   Complexo Portuário              701048 non-null  object
#  7   Tipo da Autoridade Portuária    701048 non-null  object
#  8   Data Atracação                  698635 non-null  object
#  9   Data Chegada                    698635 non-null  object
#  10  Data Desatracação               701048 non-null  object
#  11  Data Início Operação            666551 non-null  object
# ...

# %%
#verificar colunas
print(df.columns)
# Out:
# Index(['IDAtracacao', 'CDTUP', 'IDBerco', 'Berço', 'Porto Atracação',
#        'Apelido Instalação Portuária', 'Complexo Portuário',
#        'Tipo da Autoridade Portuária', 'Data Atracação', 'Data Chegada',
#        'Data Desatracação', 'Data Início Operação', 'Data Término Operação',
#        'Ano', 'Mes', 'Tipo de Operação', 'Tipo de Navegação da Atracação',
#        'Nacionalidade do Armador', 'FlagMCOperacaoAtracacao', 'Terminal',
#        'Município', 'UF', 'SGUF', 'Região Geográfica', 'Nº da Capitania',
#        'Nº do IMO'],
#       dtype='object')

# %%
#formato células Data Chegada
df ['Data Chegada'] = pd.to_datetime (df['Data Chegada'], format='%d/%m/%Y %H:%M:%S')
df ['Data Atracação'] = pd.to_datetime (df['Data Atracação'], format='%d/%m/%Y %H:%M:%S')
df ['Data Início Operação'] = pd.to_datetime (df['Data Início Operação'], format='%d/%m/%Y %H:%M:%S')
df ['Data Término Operação'] = pd.to_datetime (df['Data Término Operação'], format='%d/%m/%Y %H:%M:%S')
df ['Data Desatracação'] = pd.to_datetime (df['Data Desatracação'], format='%d/%m/%Y %H:%M:%S')

# %%
#TEMPO ENTRE DUAS OPERAÇÕES CHEGADA - ATRACAÇÃO
df['Tempo_espera_atracar'] = round((df['Data Atracação'] - df['Data Chegada']).dt.total_seconds()/3600,2)
df['Tempo_atracação_início'] = round((df['Data Início Operação'] - df['Data Atracação']).dt.total_seconds()/3600,2)
df['Tempo_fim_operação'] = round((df['Data Término Operação'] - df['Data Início Operação']).dt.total_seconds()/3600,2)
df['Tempo_desatracação'] = round((df['Data Desatracação'] - df['Data Término Operação']).dt.total_seconds()/3600,2)

# %%
# Verificando as primeiras linhas do dataframe final
df.head(5)
# Out:
#    IDAtracacao    CDTUP      IDBerco                Berço  \
# 0       691715  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 1       691712  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 2       691731  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 3       697535  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
# 4       702879  BRAM014  BRAM0140304  BERÇO - 02  INTERNA
#
#                Porto Atracação Apelido Instalação Portuária  \
# 0  Terminal Graneleiro Hermasa                          NaN
# 1  Terminal Graneleiro Hermasa                          NaN
# 2  Terminal Graneleiro Hermasa                          NaN
# 3  Terminal Graneleiro Hermasa                          NaN
# 4  Terminal Graneleiro Hermasa                          NaN
#
#   Complexo Portuário Tipo da Autoridade Portuária      Data Atracação  \
# 0             Manaus                Porto Privado 2015-05-28 19:23:00
# 1             Manaus                Porto Privado 2015-05-28 10:11:00
# ...

# %%
# Salvando o arquivo final em um arquivo csv
df.to_csv('/content/drive/My Drive/PYTHON/Dados Atracacao/dataframe_final_dados.csv',index=False)
